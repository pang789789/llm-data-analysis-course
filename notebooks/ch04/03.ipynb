# %%
환경확인과 4개 CSV 불러오기
-customers
-orders

# %%
from course_utils.paths import get_project_root, get_data_dir
import pandas as pd

print(get_data_dir())

customers = pd.read_csv(get_data_dir() / "raw/customers.csv")
orders = pd.read_csv(get_data_dir() / "raw/orders.csv")

print(customers.info())
print(orders.info())
# Out:
# C:\dev\llm-data-analysis-course\data
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  150 non-null    int64
#  1   name         150 non-null    str
#  2   gender       150 non-null    str
#  3   age          150 non-null    int64
#  4   city         150 non-null    str
#  5   signup_date  150 non-null    str
# dtypes: int64(2), str(4)
# memory usage: 7.2 KB
# None
# <class 'pandas.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        300 non-null    int64
#  1   customer_id     300 non-null    int64
#  2   order_date      300 non-null    str
#  3   payment_method  300 non-null    str
#  4   order_status    300 non-null    str
# dtypes: int64(2), str(3)
# memory usage: 11.8 KB
# None

# %%
products = pd.read_csv(get_data_dir() / "raw/products.csv")
order_items = pd.read_csv(get_data_dir() / "raw/order_items.csv")

print(products.info())
print(order_items.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    100 non-null    int64
#  1   product_name  100 non-null    str
#  2   category      100 non-null    str
#  3   price         100 non-null    int64
# dtypes: int64(2), str(2)
# memory usage: 3.3 KB
# None
# <class 'pandas.DataFrame'>
# RangeIndex: 764 entries, 0 to 763
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_item_id  764 non-null    int64
#  1   order_id       764 non-null    int64
#  2   product_id     764 non-null    int64
#  3   quantity       764 non-null    int64
#  4   unit_price     764 non-null    int64
# dtypes: int64(5)
# memory usage: 30.0 KB
# None

# %%
# orders의 상위 5개
print(orders.head())
# Out:
#    order_id  customer_id  order_date payment_method order_status
# 0         1          123  2026-05-07           card    completed
# 1         2           77  2025-07-23      naver_pay    cancelled
# 2         3          138  2025-11-19  bank_transfer    cancelled
# 3         4           57  2026-01-30      kakao_pay    cancelled
# 4         5          125  2025-12-21           card    cancelled

# %%
# 주문 상태의 종류는 몇 가지이고 각 상태별 주문 수량??
ret = orders["order_status"].value_counts(dropna=False)
print(type(ret))
print(ret)

# 결제 수단의 종류는 몇 가지이고 각 결제 상태별 주문수량??
ret = orders["payment_method"].value_counts(dropna=False)
# Out:
# <class 'pandas.Series'>
# order_status
# completed    184
# cancelled     64
# refunded      52
# Name: count, dtype: int64

# %%
# 나이가 30세 이상인 고객
# customers_over_30
customers["age"] >= 30

# 불리언마스크 customers[조건식]

customers_over_30 = customers[customers["age"] >= 30]

print(customers_over_30)
# Out:
#      customer_id name gender  age city signup_date
# 1              2  김정호      F   32   대구  2025-11-02
# 2              3  이경수      F   61   성남  2024-06-12
# 3              4  조영호      F   55   울산  2026-04-13
# 5              6  김지원      F   32   성남  2026-06-27
# 6              7  이상현      F   53   인천  2024-12-12
# ..           ...  ...    ...  ...  ...         ...
# 141          142  하서연      F   32   서울  2023-08-09
# 142          143  김예은      F   43   대전  2024-01-02
# 144          145  조정호      M   59   성남  2024-01-02
# 145          146  김숙자      M   61   성남  2025-12-23
# 149          150  조미영      M   40   대전  2025-12-04
#
# [111 rows x 6 columns]

# %%
# 30이상 중 제일 어린 사람과 제일 나이 많은 사람

print(customers_over_30["age"].max())
print(customers_over_30["age"].min())
# Out:
# 69
# 30

# %%
print(customers_over_30.describe())
# Out:
#        customer_id         age
# count   111.000000  111.000000
# mean     74.171171   48.711712
# std      43.773773   12.504826
# min       2.000000   30.000000
# 25%      35.500000   35.500000
# 50%      73.000000   50.000000
# 75%     113.500000   60.000000
# max     150.000000   69.000000

# %%
# 도시별 회원수

print(customers["city"].value_counts(dropna=False))
# Out:
# city
# 성남    21
# 광주    17
# 부산    16
# 대구    15
# 서울    15
# 울산    14
# 인천    14
# 대전    14
# 수원    13
# 고양    11
# Name: count, dtype: int64

# %%
print(customers["city"].unique())
# Out:
# <StringArray>
# ['광주', '대구', '성남', '울산', '부산', '인천', '수원', '서울', '대전', '고양']
# Length: 10, dtype: str

# %%
# 서울 부산 인천 도시의 고객들
# and &
# or |
# not ~

city_customers = customers[customers["city"].isin(["서울","부산","인천"])]

print(city_customers.head(10))
# Out:
#     customer_id name gender  age city signup_date
# 4             5  이예원      F   19   부산  2024-09-13
# 6             7  이상현      F   53   인천  2024-12-12
# 8             9  송지민      M   69   서울  2025-10-19
# 14           15  장정식      M   69   서울  2026-06-04
# 15           16  강보람      M   52   부산  2024-07-23
# 18           19  김성수      M   54   인천  2024-08-27
# 19           20  백영호      F   20   인천  2024-11-08
# 20           21  박중수      M   23   인천  2026-04-02
# 29           30  이민재      F   32   서울  2023-07-14
# 39           40  박예준      M   23   서울  2024-06-02

# %%
print(city_customers)

# %%
# 컬럼추가

print(order_items.info())

# 라인 합계 금액 : line_total = quntity * unit_price

order_items["line_total"] = order_items["quantity"]*order_items["unit_price"]

print(order_items.head(10))
print(order_items)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 764 entries, 0 to 763
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_item_id  764 non-null    int64
#  1   order_id       764 non-null    int64
#  2   product_id     764 non-null    int64
#  3   quantity       764 non-null    int64
#  4   unit_price     764 non-null    int64
#  5   line_total     764 non-null    int64
# dtypes: int64(6)
# memory usage: 35.9 KB
# None
#    order_item_id  order_id  product_id  quantity  unit_price  line_total
# 0              1         1         100         3      102000      306000
# 1              2         1          87         5       25000      125000
# 2              3         1           7         3      142000      426000
# 3              4         1           9         3      193000      579000
# 4              5         2          72         4      189000      756000
# 5              6         3          33         5      124000      620000
# 6              7         3          20         3       80000      240000
# 7              8         3          11         5      115000      575000
# 8              9         4          45         3       62000      186000
# 9             10         4          84         4       78000      312000

# %%
print(orders["order_id"].duplicated().sum())
# Out:
# 0

# %%
# order_status를 함쎼 출력 하려면  merge하기

order_sales = order_items.merge(
    orders[["order_id","customer_id","order_date","order_status"]],
    on="order_id", how="left", validate="many_to_one"
)

print(order_sales.head())
# Out:
#    order_item_id  order_id  product_id  quantity  unit_price  line_total  \
# 0              1         1         100         3      102000      306000
# 1              2         1          87         5       25000      125000
# 2              3         1           7         3      142000      426000
# 3              4         1           9         3      193000      579000
# 4              5         2          72         4      189000      756000
#
#    customer_id  order_date order_status
# 0          123  2026-05-07    completed
# 1          123  2026-05-07    completed
# 2          123  2026-05-07    completed
# 3          123  2026-05-07    completed
# 4           77  2025-07-23    cancelled

# %%
# orders 
print(orders.info())
print("order 데이터 타입 :" ,orders["order_date"].dtype)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        300 non-null    int64
#  1   customer_id     300 non-null    int64
#  2   order_date      300 non-null    str
#  3   payment_method  300 non-null    str
#  4   order_status    300 non-null    str
# dtypes: int64(2), str(3)
# memory usage: 11.8 KB
# None
# order 데이터 타입 : str

# %%
order_salse_test = order_sales.copy()

print(order_salse_test.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 764 entries, 0 to 763
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_item_id  764 non-null    int64
#  1   order_id       764 non-null    int64
#  2   product_id     764 non-null    int64
#  3   quantity       764 non-null    int64
#  4   unit_price     764 non-null    int64
#  5   line_total     764 non-null    int64
#  6   customer_id    764 non-null    int64
#  7   order_date     764 non-null    str
#  8   order_status   764 non-null    str
# dtypes: int64(7), str(2)
# memory usage: 53.8 KB
# None

# %%
order_salse_test["order_date"] = pd.to_datetime(
    order_salse_test["order_date"]
)

print(order_salse_test.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 764 entries, 0 to 763
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_item_id  764 non-null    int64
#  1   order_id       764 non-null    int64
#  2   product_id     764 non-null    int64
#  3   quantity       764 non-null    int64
#  4   unit_price     764 non-null    int64
#  5   line_total     764 non-null    int64
#  6   customer_id    764 non-null    int64
#  7   order_date     764 non-null    datetime64[us]
#  8   order_status   764 non-null    str
# dtypes: datetime64[us](1), int64(7), str(1)
# memory usage: 53.8 KB
# None

# %%
order_sales_test2 = order_sales.copy()

print(order_sales_test2.head())
# Out:
#    order_item_id  order_id  product_id  quantity  unit_price  line_total  \
# 0              1         1         100         3      102000      306000
# 1              2         1          87         5       25000      125000
# 2              3         1           7         3      142000      426000
# 3              4         1           9         3      193000      579000
# 4              5         2          72         4      189000      756000
#
#    customer_id  order_date order_status
# 0          123  2026-05-07    completed
# 1          123  2026-05-07    completed
# 2          123  2026-05-07    completed
# 3          123  2026-05-07    completed
# 4           77  2025-07-23    cancelled

# %%
order_sales_test2.loc[0,"order_date"] = "2026-02-30"
print(order_sales_test2.head())
# str이라서 2월 30일도 가능
# Out:
#    order_item_id  order_id  product_id  quantity  unit_price  line_total  \
# 0              1         1         100         3      102000      306000
# 1              2         1          87         5       25000      125000
# 2              3         1           7         3      142000      426000
# 3              4         1           9         3      193000      579000
# 4              5         2          72         4      189000      756000
#
#    customer_id  order_date order_status
# 0          123  2026-02-30    completed
# 1          123  2026-05-07    completed
# 2          123  2026-05-07    completed
# 3          123  2026-05-07    completed
# 4           77  2025-07-23    cancelled

# %%
order_sales_test2["order_date"] = pd.to_datetime(
    order_sales_test2["order_date"],
    errors="coerce"
)

print(order_sales_test2.info())
print(order_sales_test2.head(5))
print(order_sales_test2["order_date"].isna().sum())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 764 entries, 0 to 763
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_item_id  764 non-null    int64
#  1   order_id       764 non-null    int64
#  2   product_id     764 non-null    int64
#  3   quantity       764 non-null    int64
#  4   unit_price     764 non-null    int64
#  5   line_total     764 non-null    int64
#  6   customer_id    764 non-null    int64
#  7   order_date     763 non-null    datetime64[us]
#  8   order_status   764 non-null    str
# dtypes: datetime64[us](1), int64(7), str(1)
# memory usage: 53.8 KB
# None
#    order_item_id  order_id  product_id  quantity  unit_price  line_total  \
# 0              1         1         100         3      102000      306000
# 1              2         1          87         5       25000      125000
# 2              3         1           7         3      142000      426000
# 3              4         1           9         3      193000      579000
# 4              5         2          72         4      189000      756000
#
#    customer_id order_date order_status
# 0          123        NaT    completed
# 1          123 2026-05-07    completed
# 2          123 2026-05-07    completed
# 3          123 2026-05-07    completed
# 4           77 2025-07-23    cancelled
# 1
# C:\Users\Pang\AppData\Local\Temp\ipykernel_27084\803209493.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   order_sales_test2["order_date"] = pd.to_datetime(

# %%
order_sales_test2 = order_sales_test2.dropna()
print(order_sales_test2["order_date"].isna().sum())
# Out:
# 0

# %%
# 파생컬럼 order_month추가하고 0으로 초기화

# order_sales_test2["order_month"] = 0
order_sales_test2["order_month"] = order_sales_test2["order_date"].dt.to_period("M").astype(str)

# %%
print(order_sales_test2.head())
# Out:
#    order_item_id  order_id  product_id  quantity  unit_price  line_total  \
# 1              2         1          87         5       25000      125000
# 2              3         1           7         3      142000      426000
# 3              4         1           9         3      193000      579000
# 4              5         2          72         4      189000      756000
# 5              6         3          33         5      124000      620000
#
#    customer_id order_date order_status order_month
# 1          123 2026-05-07    completed     2026-05
# 2          123 2026-05-07    completed     2026-05
# 3          123 2026-05-07    completed     2026-05
# 4           77 2025-07-23    cancelled     2025-07
# 5          138 2025-11-19    cancelled     2025-11
