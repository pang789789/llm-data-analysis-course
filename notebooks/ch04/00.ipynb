# %%
from pathlib import Path
import sys

print('python tlfgod vkdlf:', sys.executable)
print('현재 작업 폴더:',Path.cwd())
# Out:
# python tlfgod vkdlf: c:\dev\llm-data-analysis-course\.venv\Scripts\python.exe
# 현재 작업 폴더: c:\dev\llm-data-analysis-course\notebooks

# %%
# %pip install matplotlib seaborn
# Out:
# ...
#   Using cached matplotlib-3.11.1-cp314-cp314-win_amd64.whl.metadata (80 kB)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pillow-12.3.0-cp314-cp314-win_amd64.whl.metadata (9.3 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
# Using cached matplotlib-3.11.1-cp314-cp314-win_amd64.whl (9.5 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached contourpy-1.3.3-cp314-cp314-win_amd64.whl (232 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

PROJECT_ROOT = Path.cwd()
# print('PROJECT_ROOT 1:'PROJECT_ROOT)

# PROJECT_ROOT = PROJECT_ROOT.parent 2. 그래서 위에다가 빼줌
# print('PROJECT_ROOT 2:'PROJECT_ROOT)

if not (PROJECT_ROOT / "data" / "raw").exists() and (PROJECT_ROOT.parent / "data" / "raw").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
#  print('PROJECT_ROOT 2:'PROJECT_ROOT) 1. 여기에 있으면 실행이 안 됨

DATA_DIR = PROJECT_ROOT / "data" / "raw"

sns.set_theme(style="whitegrid")

print("프로젝트 루트:", PROJECT_ROOT)
print("데이터 폴더:", DATA_DIR)
print("데이터 폴더 존재 여부:", DATA_DIR.exists())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#       5
# ----> 6 PROJECT_ROOT = Path.cwd()
#       7 # print('PROJECT_ROOT 1:'PROJECT_ROOT)
#       8
#       9 # PROJECT_ROOT = PROJECT_ROOT.parent 2. 그래서 위에다가 빼줌
#
# NameError: name 'Path' is not defined

# %%
# print(type(DATA_DIR))

#df_customers = pd.read_csv(DATA_DIR + "/customers.csv")
# 경로와 파일명을 연결하려고 하는데 타입에러가 났어요
#아래 방법으로 해결
df_customers = pd.read_csv(DATA_DIR / "customers.csv")

df_customers.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       2
#       3 #df_customers = pd.read_csv(DATA_DIR + "/customers.csv")
#       4 # 경로와 파일명을 연결하려고 하는데 타입에러가 났어요
#       5 #아래 방법으로 해결
# ----> 6 df_customers = pd.read_csv(DATA_DIR / "customers.csv")
#       7
#       8 df_customers.info()
#
# NameError: name 'pd' is not defined

# %%
columns = df_customers.columns.tolist()

for col in columns:
    print(col)

# %%
ustomers = df_customers.copy()

customers_over_30 = customers[
    customers["age"] >= 30

]

# customers_over_30 = customers[customers["age"] >= 30] 한줄로도 작성 가능
