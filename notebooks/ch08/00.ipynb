# %%
import os
print(os.getcwd())
# Out:
# c:\dev\llm-data-analysis-course\notebooks\ch08

# %%
import pandas as pd
import numpy as np

customers = pd.read_csv("../../data/raw/customers.csv") 
orders = pd.read_csv("../../data/raw/orders.csv")
order_items = pd.read_csv("../../data/raw/order_items.csv")
products = pd.read_csv("../../data/raw/products.csv")

print(customers.head())
print(orders.head())
print(order_items.head())
print(products.head())
# Out:
#    customer_id name gender  age city signup_date
# 0            1  김수민      F   19   광주  2024-08-21
# 1            2  김정호      F   32   대구  2026-01-04
# 2            3  이경수      F   61   성남  2024-08-14
# 3            4  조영호      F   55   울산  2026-06-15
# 4            5  이예원      F   19   부산  2024-11-15
#    order_id  customer_id  order_date payment_method order_status
# 0         1          123  2026-07-09           card    completed
# 1         2           77  2025-09-24      naver_pay    cancelled
# 2         3          138  2026-01-21  bank_transfer    cancelled
# 3         4           57  2026-04-03      kakao_pay    cancelled
# 4         5          125  2026-02-22           card    cancelled
#    order_item_id  order_id  product_id  quantity  unit_price
# 0              1         1         100         3      102000
# 1              2         1          87         5       25000
# 2              3         1           7         3      142000
# 3              4         1           9         3      193000
# 4              5         2          72         4      189000
#    product_id product_name category   price
# 0           1  전자기기 상품 001     전자기기  160000
# 1           2    도서 상품 002       도서   34000
# 2           3  전자기기 상품 003     전자기기  152000
# 3           4  생활용품 상품 004     생활용품   70000
# 4           5    식품 상품 005       식품  186000

# %% [markdown]
# 원본 구조에 대한 Evidence 를 만든다.

# %%
raw_data = {"customers" : customers, "orders" : orders, "order_items" : order_items, "products" : products}

print(raw_data)
# Out:
# {'customers':      customer_id name gender  age city signup_date
# 0              1  김수민      F   19   광주  2024-08-21
# 1              2  김정호      F   32   대구  2026-01-04
# 2              3  이경수      F   61   성남  2024-08-14
# 3              4  조영호      F   55   울산  2026-06-15
# 4              5  이예원      F   19   부산  2024-11-15
# ..           ...  ...    ...  ...  ...         ...
# 145          146  김숙자      M   61   성남  2026-02-24
# 146          147  이정남      M   19   부산  2025-04-15
# 147          148  오도현      M   29   고양  2026-08-17
# 148          149  김정자      M   20   부산  2024-12-21
# 149          150  조미영      M   40   대전  2026-02-05
#
# [150 rows x 6 columns], 'orders':      order_id  customer_id  order_date payment_method order_status
# 0           1          123  2026-07-09           card    completed
# 1           2           77  2025-09-24      naver_pay    cancelled
# 2           3          138  2026-01-21  bank_transfer    cancelled
# 3           4           57  2026-04-03      kakao_pay    cancelled
# 4           5          125  2026-02-22           card    cancelled
# ..        ...          ...         ...            ...          ...
# 295       296          116  2026-04-06           card    completed
# 296       297           22  2026-03-19  bank_transfer    completed
# 297       298           64  2026-02-26      naver_pay    cancelled
# 298       299          135  2025-10-10  bank_transfer    completed
# 299       300           96  2026-04-29      kakao_pay    cancelled
#
# [300 rows x 5 columns], 'order_items':      order_item_id  order_id  product_id  quantity  unit_price
# 0                1         1         100         3      102000
# 1                2         1          87         5       25000
# 2                3         1           7         3      142000
# 3                4         1           9         3      193000
# 4                5         2          72         4      189000
# ..             ...       ...         ...       ...         ...
# 759            760       297          42         4       28000
# 760            761       298          40         4      174000
# 761            762       299           8         2      189000
# 762            763       299          12         4      175000
# 763            764       300          59         5       32000
#
# [764 rows x 5 columns], 'products':     product_id product_name category   price
# 0            1  전자기기 상품 001     전자기기  160000
# 1            2    도서 상품 002       도서   34000
# 2            3  전자기기 상품 003     전자기기  152000
# 3            4  생활용품 상품 004     생활용품   70000
# 4            5    식품 상품 005       식품  186000
# ..         ...          ...      ...     ...
# 95          96  생활용품 상품 096     생활용품  112000
# 96          97  전자기기 상품 097     전자기기  154000
# 97          98   스포츠 상품 098      스포츠   10000
# 98          99    뷰티 상품 099       뷰티  200000
# 99         100    도서 상품 100       도서  102000
#
# [100 rows x 4 columns]}

# %%
# 딕셔너리 하나씩 꺼내보기

for name, frame in raw_data.items():
    print(name)
# Out:
# customers
# orders
# order_items
# products

# %%
summary_list = []
for name, frame in raw_data.items():
    # print(name)
    info = {
        "dataset": name,
        "rows": len(frame),
        "clums":frame.shape[1],
        "missing_valus":frame.isna().sum(),
        "duplicated_rows":frame.duplicated().sum(),
    }
    summary_list.append(info)

# %%
summary_list
# Out:
# [{'dataset': 'customers',
#   'rows': 150,
#   'clums': 6,
#   'missing_valus': customer_id    0
#   name           0
#   gender         0
#   age            0
#   city           0
#   signup_date    0
#   dtype: int64,
#   'duplicated_rows': np.int64(0)},
#  {'dataset': 'orders',
#   'rows': 300,
#   'clums': 5,
#   'missing_valus': order_id          0
#   customer_id       0
#   order_date        0
#   payment_method    0
#   order_status      0
#   dtype: int64,
#   'duplicated_rows': np.int64(0)},
#  {'dataset': 'order_items',
#   'rows': 764,
#   'clums': 5,
#   'missing_valus': order_item_id    0
#   order_id         0
#   product_id       0
#   quantity         0
#   unit_price       0
#   dtype: int64,
#   'duplicated_rows': np.int64(0)},
#  {'dataset': 'products',
#   'rows': 100,
#   'clums': 4,
#   'missing_valus': product_id      0
#   product_name    0
#   category        0
#   price           0
#   dtype: int64,
#   'duplicated_rows': np.int64(0)}]

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parents[1]

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %%
import pandas as pd

customers = pd.read_csv("../../data/raw/customers.csv")
orders = pd.read_csv("../../data/raw/orders.csv")
order_items = pd.read_csv("../../data/raw/order_items.csv")
products = pd.read_csv("../../data/raw/products.csv")

raw_data = {
    "customers": customers,
    "orders": orders,
    "order_items": order_items,
    "products": products,
}

# %%
from src.preprocessing import (
    compare_shapes,
    preprocess_sales_data,
    validate_relationships,
)

processed_data = preprocess_sales_data(raw_data)
preprocessing_comparison = compare_shapes(
    raw_data,
    processed_data,
)

relationship_checks = validate_relationships(
    processed_data
)

# %%
from src.preprocessing import compare_shapes,preprocess_sales_data

Processing_data = preprocess_sales_data(raw_data)
preprocessing_comparison = compare_shapes(raw_data, processed_data)

# %%
preprocessing_comparison
# Out:
#        dataset  rows_raw  columns_raw  rows_processed  columns_processed
# 0    customers       150            6             150                  6
# 1  order_items       764            5             764                  6
# 2       orders       300            5             300                  7
# 3     products       100            4             100                  4

# %%
print(raw_data["order_items"].columns)
print(processed_data["order_items"].columns)
# Out:
# Index(['order_item_id', 'order_id', 'product_id', 'quantity', 'unit_price'], dtype='str')
# Index(['order_item_id', 'order_id', 'product_id', 'quantity', 'unit_price',
#        'line_total'],
#       dtype='str')

# %%
print(raw_data["orders"].columns)
print(processed_data["orders"].columns)
# Out:
# Index(['order_id', 'customer_id', 'order_date', 'payment_method',
#        'order_status'],
#       dtype='str')
# Index(['order_id', 'customer_id', 'order_date', 'payment_method',
#        'order_status', 'order_month', 'order_dayofweek'],
#       dtype='str')

# %%
# order_dayofweek 가 뭔지 확인

print(processed_data["orders"].head())
# Out:
#    order_id  customer_id order_date payment_method order_status order_month  \
# 0         1          123 2026-07-09           card    completed     2026-07
# 1         2           77 2025-09-24      naver_pay    cancelled     2025-09
# 2         3          138 2026-01-21  bank_transfer    cancelled     2026-01
# 3         4           57 2026-04-03      kakao_pay    cancelled     2026-04
# 4         5          125 2026-02-22           card    cancelled     2026-02
#
#   order_dayofweek
# 0        Thursday
# 1       Wednesday
# 2       Wednesday
# 3          Friday
# 4          Sunday

# %%
print(processed_data["orders"]["order_dayofweek"].value_counts())
# Out:
# order_dayofweek
# Saturday     50
# Tuesday      47
# Monday       47
# Wednesday    44
# Sunday       43
# Friday       35
# Thursday     34
# Name: count, dtype: int64

# %%
key_map = {
    "customers":"customer_id",
    "orders":"order_id",
    "order_items":"order_item_id",
    "products":"product_id",
}

# %%
kp_checks = []

for dataset, key in key_map.items():
    frame = processed_data[dataset]
    missing_count = int(frame[key].isna().sum())
    duplicated_count = int(frame[key].duplicated().sum())

    #status = ""
    #if missing_count == 0 and duplicated_count == 0
    #    status = "pass"
    #else
    #    status = "False"

    kp_checks.append(
        {
            "dataset":dataset,
            "key": key,
            "missing_count":missing_count,
            "duplicated_count":duplicated_count,
            "status": (
                "pass"
                if missing_count == 0 and duplicated_count == 0
                else "fail"
            ),
        }
    )

# %% [markdown]
# 검증

# %%
order_sales = order_items.merge(
    orders[
        [
            "order_id",
            "customer_id",
            "order_date",
            "order_status",
        ]
    ],

    on="order_id",
    how="left",
    validate="many_to_one",
    indicator=True,
)

# %%
order_sales.head()
# Out:
#    order_item_id  order_id  product_id  quantity  unit_price  customer_id  \
# 0              1         1         100         3      102000          123
# 1              2         1          87         5       25000          123
# 2              3         1           7         3      142000          123
# 3              4         1           9         3      193000          123
# 4              5         2          72         4      189000           77
#
#    order_date order_status _merge
# 0  2026-07-09    completed   both
# 1  2026-07-09    completed   both
# 2  2026-07-09    completed   both
# 3  2026-07-09    completed   both
# 4  2025-09-24    cancelled   both

# %% [markdown]
# 확인 해야 되는 항목

# %% [markdown]
# 오른쪽 키 고유성
# 병합 관계 validate
# 병합 전 행 수
# 병합 후 행 수
# 미매칭 행 수

# %%
print("병합 전 행 수 :",len(order_items))
print("병합 후 행 수 :",len(order_sales))
print(order_sales["_merge"].value_counts(dropna=False))
# Out:
# 병합 전 행 수 : 764
# 병합 후 행 수 : 764
# _merge
# both          764
# left_only       0
# right_only      0
# Name: count, dtype: int64

# %%
excepted_line_total = order_items["quantity"]*order_items["unit_price"]
excepted_line_total
# Out:
# 0      306000
# 1      125000
# 2      426000
# 3      579000
# 4      756000
#         ...
# 759    112000
# 760    696000
# 761    378000
# 762    700000
# 763    160000
# Length: 764, dtype: int64

# %% [markdown]
# 몇가지 검증

# %%
if "line_total" not in order_items.columns:
    # 파생 컬럼 생성
    order_items["line_total"] = excepted_line_total

order_items.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 764 entries, 0 to 763
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_item_id  764 non-null    int64
#  1   order_id       764 non-null    int64
#  2   product_id     764 non-null    int64
#  3   quantity       764 non-null    int64
#  4   unit_price     764 non-null    int64
#  5   line_total     764 non-null    int64
# dtypes: int64(6)
# memory usage: 35.9 KB

# %% [markdown]
# completed 범위를 확정한 뒤 금액을 집계합니다

# %%
# completed_order_sales = order_sales[조건식] 불리언 마스크
completed_order_sales = order_sales.loc[
    order_sales["order_status"].eq("completed")
].copy()

print(completed_order_sales.head())
print(completed_order_sales["order_status"].value_counts())
# Out:
#     order_item_id  order_id  product_id  quantity  unit_price  customer_id  \
# 0               1         1         100         3      102000          123
# 1               2         1          87         5       25000          123
# 2               3         1           7         3      142000          123
# 3               4         1           9         3      193000          123
# 12             13         6          83         3       24000           87
#
#     order_date order_status _merge
# 0   2026-07-09    completed   both
# 1   2026-07-09    completed   both
# 2   2026-07-09    completed   both
# 3   2026-07-09    completed   both
# 12  2026-05-23    completed   both
# order_status
# completed    474
# Name: count, dtype: int64

# %%
print("전체 주문 건수 :", len(order_sales))
print("전체 주문 건수(completed) :", len(completed_order_sales))
print("전체 주문 건수(completed 외) :", len(order_sales) - len(completed_order_sales))
# Out:
# 전체 주문 건수 : 764
# 전체 주문 건수(completed) : 474
# 전체 주문 건수(completed 외) : 290

# %%
order_sales["order_status"].value_counts()
# Out:
# order_status
# completed    474
# cancelled    162
# refunded     128
# Name: count, dtype: int64

# %%
# 카테고리별 집계
order_status_sales = (
    completed_order_sales
    .groupby("order_status", as_index=False)
    .agg(
        total_quantity=("quantity","sum"),
        total_sales = ("line_total", "sum")
    )
    .sort_values("total_sales",ascending=False)
)
# Out:
# ['order_item_id', 'order_id', 'product_id', 'quantity', 'unit_price', 'customer_id', 'order_date', 'order_status', '_merge']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[65], line 6
#       2 print(completed_order_sales.columns.tolist())
#       3 order_status_sales = (
#       4     completed_order_sales
#       5     .groupby("order_status", as_index=False)
# ----> 6     .agg(
#       7         total_quantity=("quantity","sum"),
#       8         total_sales = ("line_total", "sum")
#       9     )
#
# File c:\dev\llm-data-analysis-course\.venv-new\Lib\site-packages\pandas\core\groupby\generic.py:2291, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    2288     kwargs["engine_kwargs"] = engine_kwargs
#    2290 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 2291 result = op.agg()
#    2292 if not is_dict_like(func) and result is not None:
#    2293     # GH #52849
#    2294     if not self.as_index and is_list_like(func):
#
# File c:\dev\llm-data-analysis-course\.venv-new\Lib\site-packages\pandas\core\apply.py:294, in Apply.agg(self)
#     291     return self.apply_str()
#     293 if is_dict_like(func):
# --> 294     return self.agg_dict_like()
#     295 elif is_list_like(func):
#     296     # we require a list, but not a 'str'
#     297     return self.agg_list_like()
#
# File c:\dev\llm-data-analysis-course\.venv-new\Lib\site-packages\pandas\core\apply.py:511, in Apply.agg_dict_like(self)
#     503 def agg_dict_like(self) -> DataFrame | Series:
#     504     """
#     505     Compute aggregation in the case of a dict-like argument.
#     506
#    (...)    509     Result of aggregation.
#     510     """
# --> 511     return self.agg_or_apply_dict_like(op_name="agg")
#
# File c:\dev\llm-data-analysis-course\.venv-new\Lib\site-packages\pandas\core\apply.py:1677, in GroupByApply.agg_or_apply_dict_like(self, op_name)
#    1672     kwargs.update({"engine": engine, "engine_kwargs": engine_kwargs})
#    1674 with com.temp_setattr(
#    1675     obj, "as_index", True, condition=hasattr(obj, "as_index")
#    1676 ):
# -> 1677     result_index, result_data = self.compute_dict_like(
#    1678         op_name, selected_obj, selection, kwargs
#    1679     )
#    1680 result = self.wrap_results_dict_like(selected_obj, result_index, result_data)
#    1681 return result
#
# File c:\dev\llm-data-analysis-course\.venv-new\Lib\site-packages\pandas\core\apply.py:550, in Apply.compute_dict_like(self, op_name, selected_obj, selection, kwargs)
#     548 is_groupby = isinstance(obj, (DataFrameGroupBy, SeriesGroupBy))
#     549 func = cast(AggFuncTypeDict, self.func)
# --> 550 func = self.normalize_dictlike_arg(op_name, selected_obj, func)
#     552 is_non_unique_col = (
#     553     selected_obj.ndim == 2
#     554     and selected_obj.columns.nunique() < len(selected_obj.columns)
#     555 )
#     557 if selected_obj.ndim == 1:
#     558     # key only used for output
#
# File c:\dev\llm-data-analysis-course\.venv-new\Lib\site-packages\pandas\core\apply.py:762, in Apply.normalize_dictlike_arg(self, how, obj, func)
#     759     cols = Index(list(func.keys())).difference(obj.columns, sort=True)
#     760     if len(cols) > 0:
#     761         # GH 58474
# --> 762         raise KeyError(f"Label(s) {list(cols)} do not exist")
#     764 aggregator_types = (list, tuple, dict)
#     766 # if we have a dict of any non-scalars
#     767 # eg. {'A' : ['mean']}, normalize all to
#     768 # be list-likes
#     769 # Cannot use func.values() because arg may be a Series
#
# KeyError: "Label(s) ['line_total'] do not exist"

# %%
print(completed_order_sales.columns)
print(products.head())
# Out:
# Index(['order_item_id', 'order_id', 'product_id', 'quantity', 'unit_price',
#        'customer_id', 'order_date', 'order_status', '_merge'],
#       dtype='str')
#    product_id product_name category   price
# 0           1  전자기기 상품 001     전자기기  160000
# 1           2    도서 상품 002       도서   34000
# 2           3  전자기기 상품 003     전자기기  152000
# 3           4  생활용품 상품 004     생활용품   70000
# 4           5    식품 상품 005       식품  186000
